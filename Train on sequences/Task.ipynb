# %%
import numpy
import random
import pylab
from pylab import *
from numpy import log as ln
from MNIST import train,uni_permu,train_data,train_label,test_data,test_label,f,df,decay
from MNIST import RNN

# %% [markdown]
# # MNIST task

# %%
if __name__ == '__main__':
    batches = 200
    b_size = 128
    llr = pow(10,-2)
    learn_rate = np.array([llr,llr,llr,llr,llr,llr,llr,llr,llr])
    n_in, n_rec, n_out = 28, 100, 10
    optimizer = 'Adam'
    net1 = RNN(n_in, n_rec, n_out)
    import time
    start = time.time()
    print('Training begin.')
    data,targets = uni_permu(train_data,train_label,0)
    F0,hb0 = net1.inference((data[0:500]).T.reshape(28,28,500),targets[0:500].T,0.1,f,df,0)
    CEs = [F0*1]
    accuracies = []
    Total_epoch = 100
    m_in_all=[]
    m_out_all=[]
    m_rec_all=[]
    pi_in_all=[]
    pi_out_all=[]
    pi_rec_all=[]
    sig_in_all=[]
    sig_out_all=[]
    sig_rec_all=[]        
    print("initially",CEs)
    for epoch in range(Total_epoch):
    
        print('Epoch {}'.format(epoch))
        m_in_all.append(net1.m_in*1)
        m_out_all.append(net1.m_out*1)
        m_rec_all.append(net1.m_rec*1)
            
        pi_in_all.append(net1.pi_in*1)
        pi_out_all.append(net1.pi_out*1)
        pi_rec_all.append(net1.pi_rec*1)
            
        sig_in_all.append(net1.xi_in*1)
        sig_out_all.append(net1.xi_out*1)
        sig_rec_all.append(net1.xi_rec*1)    
    





        lr = decay(epoch+1, 1e-3, learn_rate, 40)
        CE = train(net1, b_size, batches, train_data, train_label, lr,epoch)    
        CEs.append(CE[0]*1)
        accuracy = test(net1, test_data, test_label,sampling=False)
        accuracies.append(accuracy)
        #accuracy2=test(net1, test_data, test_label,sampling=True)
        print(' Accuracy = {:.2f}%.'.format(accuracy))
        print("F is",CEs)
        #print(' CE = {:.4f}; Sampling Accuracy = {:.2f}%.'.format(CE,accuracy2*100))
    end = time.time()
# Out:
# Training begin.
# err 16689.251467555063
# err_out 9.468182580059208
# initially [1879.6664343214775]
# Epoch 0
# err 59173.156216875715
# err_out 9.736222170584817
# acc1 17.1875
# acc2 10.15625
# xirec 405.3783373106335
# xirec 499.6526907963439
# Traning process: 0.50%.err 70094.45898700175
# err_out 9.917877639135535
# acc1 12.5
# acc2 12.5
# xirec 321.98630372083574
# xirec 489.0506394193801
# Traning process: 1.00%.err 301919.2791638532
# err_out 9.450950314418465
# acc1 8.59375
# acc2 10.9375
# xirec 250.69801458442967
# xirec 478.13381560623304
# Traning process: 1.50%.err 24259.408217372027
# err_out 8.675258519238035
# acc1 10.15625
# acc2 14.0625
# xirec 189.01360190834998
# xirec 458.68735593868996
# Traning process: 2.00%.err 14743.057225810877
# err_out 8.242364289561957
# acc1 17.96875
# acc2 11.71875
# xirec 137.24025489036416
# xirec 437.4411981897978
# Traning process: 2.50%.err 13544.22476020065
# err_out 8.801175295951067
# acc1 9.375
# acc2 7.8125
# ...

# %% [markdown]
# # Toy model Task

# %%
import numpy as np
from toymodel import RNN as RNN_toy
from toymodel import full_dataset2,uni_permu
import random

# %%
if __name__ == '__main__':
    M = 2
    R = 1
    N = 10
    Full_data = np.array(full_dataset2(M,R,N)).reshape(26*(M**(N)),26,1+N*R)
    train_data1 = Full_data[:,:,0:N*R]
    train_label1 = Full_data[:,:,1:N*R+1]
    er_al=[]
    n_in, n_rec, n_out = 26, 100, 26
    # for beta in [6.0,8.0,10.0,20,30,40,50,100,200,300]:
    for beta in [0.05]:
        print("beta is", beta)
        M = int(beta*n_rec)
        if M<=100:
            b_size=M
            batches=1
        if M>100:
            b_size=200
            batches = int(M/b_size)
        er_cons = []
        for i in range(1):
            print("M is", M)
            n_in, n_rec, n_out = 26, 100, 26
            net1 = RNN_toy(n_in, n_rec, n_out)
            print("initially",np.average(net1.test())*1)
            print("batches",batches)
            sample_ind = random.randint(0, 26624-int(M))
            data,targets = uni_permu(train_data1,train_label1,0)
            print("sample start",sample_ind)
            print("datasize",np.shape(data[sample_ind:sample_ind+M]))
            net1.SGD(100,b_size, batches, data[sample_ind:sample_ind+M], targets[sample_ind:sample_ind+M],0.5,20)
            er_cons.append(np.average(net1.test())*1)
        er_al.append(er_cons*1)
# Out:
# the expected length: 11
# the expected load: 26624
# beta is 0.05
# M is 5
# initially 0.06153846153846154
# batches 1
# sample start 17725
# datasize (5, 26, 10)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-5c676989d527> in <module>
#      29             print("sample start",sample_ind)
#      30             print("datasize",np.shape(data[sample_ind:sample_ind+M]))
# ---> 31             net1.SGD(100,b_size, batches, data[sample_ind:sample_ind+M], targets[sample_ind:sample_ind+M],0.5,20)
#      32             er_cons.append(np.average(net1.test())*1)
#      33         er_al.append(er_cons*1)
#
# ~/Desktop/Train on sequences/toymodel.py in SGD(self, epoch, b_size, batches, train_datax, train_labelx, start, every)
#     455             alpha = decay(i+1, 0.001,start,every)
#     456 #             print("test is",np.average(net1.xi_rec))
# ...
